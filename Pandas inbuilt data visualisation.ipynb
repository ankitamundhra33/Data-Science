# %% [markdown]
#                                             Made By - Ankita Mundhra

# %%
import pandas as pd
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
ece = pd.read_csv('ece.csv')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
ece.head()
# Out:
#   Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 0       ECTA.S19A1  2001.03         NaN         NaN      C  Dollars
# 1       ECTA.S19A1  2002.03         NaN         NaN      C  Dollars
# 2       ECTA.S19A1  2003.03         NaN         NaN      C  Dollars
# 3       ECTA.S19A1  2004.03     28005.1         NaN      F  Dollars
# 4       ECTA.S19A1  2005.03     30629.6         NaN      F  Dollars
#
#    Magnitude                                        Subject  \
# 0          6  Electronic Card Transactions (ANZSIC06) - ECT
# 1          6  Electronic Card Transactions (ANZSIC06) - ECT
# 2          6  Electronic Card Transactions (ANZSIC06) - ECT
# 3          6  Electronic Card Transactions (ANZSIC06) - ECT
# 4          6  Electronic Card Transactions (ANZSIC06) - ECT
#
#                                                Group Series_title_1  \
# 0  Total values - Electronic card transactions A/...         Actual
# ...

# %%
x1 = np.random.rand(100, 5)

# %%
x2 = np.random.rand(10, 5)

# %%
df1 = pd.DataFrame(x1, columns = ['a', 'b', 'c', 'd', 'e'])

# %%
df1.head()
# Out:
#           a         b         c         d         e
# 0  0.937782  0.198349  0.681200  0.529426  0.617265
# 1  0.450483  0.379018  0.208050  0.005154  0.716565
# 2  0.767259  0.790361  0.942268  0.310261  0.295542
# 3  0.453300  0.322447  0.131709  0.937626  0.949131
# 4  0.604942  0.773642  0.582468  0.828126  0.635203

# %%
df2 = pd.DataFrame(x2, columns = ['a', 'b', 'c', 'd', 'e'])

# %%
df2
# Out:
#           a         b         c         d         e
# 0  0.922207  0.868735  0.309997  0.451332  0.110659
# 1  0.497112  0.614378  0.117666  0.052993  0.826378
# 2  0.004241  0.414622  0.430882  0.589450  0.986563
# 3  0.274151  0.893715  0.173747  0.141336  0.875394
# 4  0.930952  0.186994  0.645774  0.929596  0.762588
# 5  0.740926  0.112626  0.389607  0.532333  0.956666
# 6  0.733776  0.095435  0.828478  0.555850  0.419674
# 7  0.160137  0.554820  0.747938  0.785491  0.996728
# 8  0.266810  0.302245  0.678688  0.777480  0.526436
# 9  0.786281  0.693030  0.533269  0.689255  0.642376

# %% [markdown]
# # Point Plots

# %%
df1.plot.scatter(x='a', y='b')

# %%
df2.plot.scatter(x='a', y='b')

# %%
tips.plot.scatter(x='total_bill', y='tip')

# %% [markdown]
# # Line Plots

# %%
df1.plot.line()

# %%
df1['a'].plot.line()

# %%
df2.plot.line()

# %%
df2['a'].plot.line()

# %%
df2.plot.kde()

# %%
df1.plot.kde()

# %%
tips.plot.kde()

# %%
df2['a'].plot.density()

# %%
df2.plot.density()

# %% [markdown]
# # Distribution Plots

# %%
df2.plot.hist()

# %%
df2.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C45CA0B4C8>,
# ...
#       dtype=object)

# %%
df2['a'].plot.hist()

# %%
df2[['c','d']].plot.hist()

# %%
df2.plot.bar()

# %%
df2['a'].plot.bar()

# %%
df2.plot.area()

# %%
df2.plot.area(alpha=0.5)

# %%
df2.plot(kind='hist')

# %%
df1.plot.box()

# %%
df1['a'].plot.box()

# %%
df1[['a','c']].plot.box()

# %%
tips.plot.hexbin(x='total_bill', y='tip', gridsize=5)

# %%
tips.plot.hexbin(x='total_bill', y='tip', gridsize=10)

# %%
df1.plot.hexbin(x='a', y='b', gridsize=10)
