# %% [markdown]
#                                         Made by - Ankita Mundhra

# %%
import seaborn as sns
import numpy as np
import pandas as pd

# %%
diamond = sns.load_dataset('diamonds')

# %% [markdown]
# Note: Diamonds.csv is one of the many inbuilt datasets of seaborn.

# %%
diamond.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.distplot(diamond['price'])

# %%
sns.rugplot(diamond['depth'])

# %%
sns.kdeplot(diamond['price'])

# %%
sns.distplot(diamond['price'], kde=False)

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.residplot(x='total_bill', y='tip', data=tips)

# %%
sns.jointplot(x='total_bill', y='tip', data=tips)

# %% [markdown]
# Note: By default, kind='scatter'

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='kde')

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex')

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex', color="#4CB391")

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='reg')

# %%
dots = sns.load_dataset('dots')

# %%
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
sns.pairplot(dots)

# %%
sns.pairplot(dots, hue='choice')

# %%
sns.pairplot(tips, hue='sex')

# %%
sns.pairplot(tips, hue='smoker')

# %%
sns.pairplot(tips, hue='day')

# %%
x = sns.pairplot(tips, hue='day')
x.map_diag(sns.distplot)

# %%
sns.countplot(x='day', data=tips)

# %%
sns.countplot(x='smoker', data=tips)

# %%
sns.pointplot(x='total_bill', y='day', data=tips)

# %%
sns.pointplot(x='day', y='total_bill', data=tips)

# %%
sns.pointplot(x='smoker', y='tip', data=tips)

# %%
sns.factorplot(x='smoker', y='tip', data=tips)
# Out:
# C:\Users\A3878355\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x='smoker', y='tip', data=tips, kind='box')

# %%
sns.factorplot(x='smoker', y='tip', data=tips, kind='bar')
# Out:
# C:\Users\A3878355\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.swarmplot(x='smoker', y='tip', data=tips)

# %%
sns.swarmplot(x='smoker', y='tip', data=tips, hue='sex')

# %%
sns.swarmplot(x='smoker', y='tip', data=tips, hue='sex', palette='cool')

# %%
sns.swarmplot(x='smoker', y='tip', data=tips, hue='sex', palette='magma')

# %%
sns.swarmplot(x='smoker', y='tip', data=tips, hue='sex', palette='coolwarm')

# %%
sns.stripplot(x='smoker', y='tip', data=tips, hue='sex', palette='cool')

# %%
sns.barplot(x='day', y='tip', data=tips)

# %%
sns.boxplot(x='day', y='tip', data=tips)

# %%
sns.boxplot(x='day', y='tip', data=tips, hue='sex')

# %%
sns.violinplot(x='day', y='tip', data=tips)

# %%
sns.violinplot(x='day', y='tip', data=tips, hue='sex')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
flights = sns.load_dataset('flights')

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
tip2 = tips.corr()

# %%
tip2
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tip2)

# %%
flight2 = flights.corr()

# %%
sns.heatmap(flight2)

# %%
sns.heatmap(tip2, annot=True)

# %%
sns.heatmap(flight2, annot=True)

# %%
sns.heatmap(tip2, annot=True, linewidths=10)

# %%
sns.heatmap(tip2, annot=True, lw=3, linecolor='green')

# %%
sns.heatmap(tip2, annot=True, lw=3, linecolor='green', cmap='cool')

# %%
flight2 = flights.pivot_table(index='month', columns='year', values='passengers')

# %%
flight2
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
sns.heatmap(flight2)

# %%
sns.heatmap(flight2, lw=1, cmap='cool')

# %%
sns.clustermap(flight2)

# %%
sns.clustermap(flight2, cmap='cool')

# %%
sns.clustermap(flight2, cmap='cool', lw=1)

# %% [markdown]
# # Styling

# %%
# %matplotlib inline

# %%
import seaborn as sns
import numpy as np
import pandas as pd

# %%
tips = sns.load_dataset('tips')

# %%
sns.countplot(x='smoker', data=tips)
sns.set_context('poster')

# %%
sns.countplot(x='smoker', data=tips)
sns.set_context('paper')

# %%
sns.countplot(x='smoker', data=tips)
sns.set_context('notebook')

# %%
sns.countplot(x='smoker', data=tips)
sns.despine()

# %%
sns.countplot(x='smoker', data=tips)
sns.despine(left=True)

# %%
sns.countplot(x='smoker', data=tips)
sns.despine(left=True, bottom=True)

# %%
sns.countplot(x='smoker', data=tips)
sns.despine(left=True, bottom=True, top=False)

# %%
sns.countplot(x='smoker', data=tips)
sns.set_style('white')

# %%
sns.countplot(x='smoker', data=tips)
sns.set_style('darkgrid')

# %%
sns.countplot(x='smoker', data=tips)
sns.set_style('whitegrid')

# %%
sns.countplot(x='smoker', data=tips)
sns.set_style('ticks')
